# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/loan_approved.csv")

# %%
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                    13
# Married                    3
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                22
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                22
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].median())

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240., 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
df['Loan_Amount_Term'].count()
# Out:
# np.int64(614)

# %%
df['Loan_Amount_Term'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Loan_Amount_Term
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB

# %%
df['Gender']=pd.get_dummies(df['Gender'],dtype=int,drop_first=True)

# %%
df['Married']=pd.get_dummies(df['Married'],dtype=int,drop_first=True)

# %%
import sklearn.preprocessing
df['Dependents']=sklearn.preprocessing.LabelEncoder().fit_transform(df['Dependents'])

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents     Education Self_Employed  \
# 0  LP001002       1        0           0      Graduate            No
# 1  LP001003       1        1           1      Graduate            No
# 2  LP001005       1        1           0      Graduate           Yes
# 3  LP001006       1        1           0  Not Graduate            No
# 4  LP001008       1        0           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
df['Education']=pd.get_dummies(df['Education'],dtype=int,drop_first=True)

# %%
df['Self_Employed']=pd.get_dummies(df['Self_Employed'],dtype=int,drop_first=True)

# %%
df['Credit_History']=pd.get_dummies(df['Credit_History'],dtype=int,drop_first=True)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0               1         Urban                      Y
# ...

# %%
df['Loan_Amount_Term']=sklearn.preprocessing.LabelEncoder().fit_transform(df['Loan_Amount_Term'])

# %%
df['Credit_History'].unique()
# Out:
# array([1, 0])

# %%
df['Credit_History']=sklearn.preprocessing.LabelEncoder().fit_transform(df['Credit_History'])

# %%
df = pd.get_dummies(df, columns=['Property_Area'], dtype=int, drop_first=True)

# %%
df['Loan_Status (Approved)']=pd.get_dummies(df['Loan_Status (Approved)'],dtype=int,drop_first=True)

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0                 8
# 1             4583             1508.0       128.0                 8
# 2             3000                0.0        66.0                 8
# 3             2583             2358.0       120.0                 8
# 4             6000                0.0       141.0                 8
#
#    Credit_History  Loan_Status (Approved)  Property_Area_Semiurban  \
# 0               1                       1                        0
# ...

# %%
mean=df['LoanAmount'].mean()

# %%
mean
# Out:
# np.float64(145.75244299674267)

# %%
m=df['ApplicantIncome'].mean()
std=df['ApplicantIncome'].std()
df['ApplicantIncome']=(df['ApplicantIncome']-m)/std

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.072931                0.0       128.0                 8
# 1        -0.134302             1508.0       128.0                 8
# 2        -0.393427                0.0        66.0                 8
# 3        -0.461686             2358.0       120.0                 8
# 4         0.097649                0.0       141.0                 8
#
#    Credit_History  Loan_Status (Approved)  Property_Area_Semiurban  \
# 0               1                       1                        0
# ...

# %%
df['ApplicantIncome'].max()
# Out:
# 12.374533479765521

# %%
df['CoapplicantIncome'].kurtosis()
# Out:
# np.float64(84.95638421103374)

# %%
df['CoapplicantIncome'].skew()
# Out:
# np.float64(7.491531216657306)

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
df['CoapplicantIncome']=pt.fit_transform(df[['CoapplicantIncome']])

# %%
df['CoapplicantIncome'].kurtosis()
# Out:
# np.float64(-1.8778432766544493)

# %%
import seaborn as sns
sns.histplot(df['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
df.to_csv('/content/drive/MyDrive/loan_approved_cleaned.csv')
